# %%
# **Water Sensor Output Legend:**
# * 0%: 0(0000); 10%: 1(0001); 20%: 2(0010);30%: 3(0011); 40%: 4(0100); 50%: 5(0101); 
# * 60%: 6(0110); 70%: 7(0111); 80%: 13(1101); 90%: 14(1110); 100%: 15(1111)
# 
# **Temperature Sensor Output Legend (in Celsius):**
# * <15: 0(000); 17.5: 1(001); 20: 2(010); 22.5: 3(011); 25: 4(100); 27.5: 5(101); 30: 6(110); 32.5: 7(111);
# 
# We have four inputs called **start**, **reset**, **water**, and **temperature**
# 
# * input **start** controls the POWER, either POWER is ON or OFF
# * input **reset**  puts the system into default state.
# * input **water** is the output of the humidity sensor 
# * input **temperature** is the output of the the temperature sensor
# 
# We have two outputs called **pump** and **ac**,
# 
# * output **pump** (water pump): ON (1) or OFF (0)
# 
# * output **ac** (Air Conditioning): A/C: Heating (11), Cooling (01) or OFF (00)
#
# * **SO**: Power is OFF (both pump and ac are closed)
# * **S1**: Default state (**pump** is ON and **ac** is OFF)
# * **S2**: Default state (**ac** is OFF)
# * **S3**: Default state (**ac** is Heating)
# * **S4**: Default state (**ac** is Cooling)
# * **S5**: Default state (**pump** is ON)
# * **S6**: Default state (**pump** is OFF)
# 
# Since **S2-S4** and **S5-S6** states are independent. We register two state variable **state_water** and **state_temperature**

import pyrtl
import io
pyrtl.reset_working_block()

# **Input** and **Output** are special type of wire, for hardware match. We need to use **Register** for states to give the decision with ".next"

start = pyrtl.Input(1, 'start')
reset = pyrtl.Input(1, 'reset')
water = pyrtl.Input(4, 'water')
temperature = pyrtl.Input(3, 'temperature')
pump = pyrtl.Output(1, 'pump')
ac = pyrtl.Output(2, 'ac')
state_water = pyrtl.Register(3, 'state_water') #S0 S1 S5 S6
state_temperature = pyrtl.Register(3, 'state_temperature') #S0 S1 S2 S3 S4

S0, S1, S2, S3, S4, S5, S6 = [pyrtl.Const(x, bitwidth=3) for x in range(7)]


# ## Create state transition and logic 
# **PyRTL has a class "ConditionalUpdate"** to provide a predicated update to a registers, wires, and memories.
# It is same as "if-else if-else" conditional states.
with pyrtl.conditional_assignment:
    with start:  # power is ON
        with reset:  # system in reset
            state_water.next |= S1
            state_temperature.next |= S1
        with pyrtl.otherwise: # functioning
            with (state_water == S0): # if previous state_water is power OFF
                state_water.next |= S1
                with (state_temperature == S0): 
                    state_temperature.next |= S1
            with (state_water == S1):
                state_water.next |= S5
                with (state_temperature == S1):
                    state_temperature.next |= S2
            with state_water == S5: # pump ON
                with water <= 14: # less than or equal to %90
                    state_water.next |= S5
                    with state_temperature == S2: #ac OFF
                        with temperature < 2: # less than 20
                            state_temperature.next |= S3
                        with temperature > 5: # higher than 27.5
                            state_temperature.next |= S4
                        with pyrtl.otherwise: # between 20 and 27.5
                            state_temperature.next |= S2
                    with state_temperature == S3: # heat untill 25
                        with temperature < 4: # less than 25
                            state_temperature.next |= S3
                        with temperature >= 4: # higher than or equal to 25
                            state_temperature.next |= S2
                    with state_temperature == S4: #cool untill 22.5
                        with temperature > 3: # higher than 22.5
                            state_temperature.next |= S4
                        with temperature <= 3: # less than or equal to 22.5
                            state_temperature.next |= S2
                with water > 14: # higher than %90
                    state_water.next |= S6
                    with state_temperature == S2: #ac OFF
                        with temperature < 2: # less than 20
                            state_temperature.next |= S3
                        with temperature > 5: # higher than 27.5
                            state_temperature.next |= S4
                        with pyrtl.otherwise: # between 20 and 27.5
                            state_temperature.next |= S2
                    with state_temperature == S3: # heat untill 25
                        with temperature < 4: # less than 25
                            state_temperature.next |= S3
                        with temperature >= 4: # higher than or equal to 25
                            state_temperature.next |= S2
                    with state_temperature == S4: #cool untill 22.5
                        with temperature > 3: # higher than 22.5
                            state_temperature.next |= S4
                        with temperature <= 3: # less than or equal to 22.5
                            state_temperature.next |= S2
            with state_water == S6: # pump OFF
                with water <= 5: # less than or equal to %50
                    state_water.next |= S5
                    with state_temperature == S2: #ac OFF
                        with temperature < 2: # less than 20
                            state_temperature.next |= S3
                        with temperature > 5: # higher than 27.5
                            state_temperature.next |= S4
                        with pyrtl.otherwise: # between 20 and 27.5
                            state_temperature.next |= S2
                    with state_temperature == S3: # heat untill 25
                        with temperature < 4: # less than 25
                            state_temperature.next |= S3
                        with temperature >= 4: # higher than or equal to 25
                            state_temperature.next |= S2
                    with state_temperature == S4: #cool untill 22.5
                        with temperature > 3: # higher than 22.5
                            state_temperature.next |= S4
                        with temperature <= 3: # less than or equal to 22.5
                            state_temperature.next |= S2
                with water > 5: # higher than %50
                    state_water.next |= S6
                    with state_temperature == S2: #ac OFF
                        with temperature < 2: # less than 20
                            state_temperature.next |= S3
                        with temperature > 5: # higher than 27.5
                            state_temperature.next |= S4
                        with pyrtl.otherwise: # between 20 and 27.5
                            state_temperature.next |= S2
                    with state_temperature == S3: # heat untill 25
                        with temperature < 4: # less than 25
                            state_temperature.next |= S3
                        with temperature >= 4: # higher than or equal to 25
                            state_temperature.next |= S2
                    with state_temperature == S4: #cool untill 22.5
                        with temperature > 3: # higher than 22.5
                            state_temperature.next |= S4
                        with temperature <= 3: # less than or equal to 22.5
                            state_temperature.next |= S2
            with pyrtl.otherwise:  
                state_water.next |= S1
                state_temperature.next |= S1
    with pyrtl.otherwise: # power OFF
        state_water.next |= S0 
        state_temperature.next |= S0

pump <<= (state_water == S1) | (state_water == S5) 
ac <<= 3*(state_temperature == S3) + (state_temperature == S4) # for S3 (heating): ac=11; for S4 (cooling): ac=01

print('--- plant_FSM Implementation ---')
print(pyrtl.working_block())
print()

sim_trace = pyrtl.SimulationTrace()
sim = pyrtl.Simulation(tracer=sim_trace)

sim_inputs = {
    'start':   '11111111111111111111100',
    'reset':   '01000000000000000000000',
    'water':   ['0', '1', '2','3', '4', '5','6','7','7', '13','14','14','15','15','14','13','7','6','5','4','3','3','3'],
    'temperature':   ['0', '1', '2','1', '2', '3','4','5','6', '6','6','5','4','4','3','3','4','5','6','1','1','1','1']
    }

for cycle in range(len(sim_inputs['start'])):
    sim.step({w: int(v[cycle]) for w, v in sim_inputs.items()})

print("--- Simulation Results ---")
sim_trace.render_trace(trace_list=['start', 'reset', 'water', 'pump', 'temperature','ac','state_water', 'state_temperature'])

print("--- Verilog for the TestBench ---")
with io.StringIO() as tbfile:
    pyrtl.output_verilog_testbench(dest_file=tbfile, simulation_trace=sim_trace)
    print(tbfile.getvalue())

pyrtl.synthesize()
pyrtl.optimize()

with io.StringIO() as vfile:
    pyrtl.output_to_verilog(dest_file=vfile)
    print(vfile.getvalue())
# Out:
# --- plant_FSM Implementation ---
# \begin{array}{ \| c \| c \| l \| }
#
# \hline
# tmp438/1W & \leftarrow s \, - & const\_45\_0/1C ((0,)) \\\hline
# tmp457/1W & \leftarrow s \, - & const\_47\_0/1C ((0,)) \\\hline
# tmp221/1W & \leftarrow s \, - & const\_29\_0/1C ((0,)) \\\hline
# tmp650/1W & \leftarrow \sim \, - & start/1I  \\\hline
# tmp651/1W & \leftarrow \sim \, - & start/1I  \\\hline
# tmp343/1W & \leftarrow s \, - & const\_38\_0/1C ((0,)) \\\hline
# tmp479/1W & \leftarrow s \, - & const\_49\_0/1C ((0,)) \\\hline
# tmp702/3W & \leftarrow s \, - & const\_61\_0/1C ((0, 0, 0)) \\\hline
# tmp606/1W & \leftarrow s \, - & const\_58\_0/1C ((0,)) \\\hline
# tmp439/3W & \leftarrow c \, - & tmp438/1W, const\_44\_3/2C  \\\hline
# tmp358/1W & \leftarrow s \, - & const\_40\_0/1C ((0,)) \\\hline
# tmp222/3W & \leftarrow c \, - & tmp221/1W, const\_28\_2/2C  \\\hline
# tmp344/4W & \leftarrow c \, - & tmp343/1W, const\_37\_5/3C  \\\hline
# tmp495/1W & \leftarrow s \, - & const\_51\_0/1C ((0,)) \\\hline
# tmp458/3W & \leftarrow c \, - & tmp457/1W, const\_46\_3/2C  \\\hline
# tmp694/1W & \leftarrow \, = \, - & state\_water/3R, const\_11\_1/3C  \\\hline
# tmp77/1W & \leftarrow \, = \, - & state\_water/3R, const\_11\_1/3C  \\\hline
# tmp359/3W & \leftarrow c \, - & tmp358/1W, const\_39\_2/2C  \\\hline
# tmp570/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp179/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp255/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp132/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp365/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp392/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp228/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp351/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp109/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp634/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp147/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp502/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp592/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp614/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp288/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp533/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp552/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp409/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp308/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp517/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp425/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp241/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp161/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp465/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp272/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp214/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp644/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp97/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp445/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp120/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp328/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp197/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp378/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp486/1W & \leftarrow \sim \, - & tmp77/1W  \\\hline
# tmp342/1W & \leftarrow \, = \, - & state\_water/3R, const\_16\_6/3C  \\\hline
# tmp480/4W & \leftarrow c \, - & tmp479/1W, const\_48\_5/3C  \\\hline
# tmp585/1W & \leftarrow s \, - & const\_56\_0/1C ((0,)) \\\hline
# tmp698/1W & \leftarrow s \, - & const\_60\_0/1C ((0,)) \\\hline
# tmp68/1W & \leftarrow \, = \, - & state\_water/3R, const\_10\_0/3C  \\\hline
# tmp189/1W & \leftarrow s \, - & const\_26\_0/1C ((0,)) \\\hline
# tmp586/3W & \leftarrow c \, - & tmp585/1W, const\_55\_3/2C  \\\hline
# tmp282/1W & \leftarrow < \, - & temperature/3I, const\_32\_4/3C  \\\hline
# tmp142/1W & \leftarrow < \, - & temperature/3I, const\_21\_4/3C  \\\hline
# tmp223/1W & \leftarrow < \, - & temperature/3I, tmp222/3W  \\\hline
# tmp419/1W & \leftarrow < \, - & temperature/3I, const\_43\_4/3C  \\\hline
# tmp360/1W & \leftarrow < \, - & temperature/3I, tmp359/3W  \\\hline
# tmp459/1W & \leftarrow > \, - & temperature/3I, tmp458/3W  \\\hline
# tmp564/1W & \leftarrow < \, - & temperature/3I, const\_54\_4/3C  \\\hline
# tmp587/1W & \leftarrow > \, - & temperature/3I, tmp586/3W  \\\hline
# tmp155/1W & \leftarrow < \, - & temperature/3I, const\_22\_4/3C  \\\hline
# tmp115/1W & \leftarrow > \, - & temperature/3I, const\_20\_5/3C  \\\hline
# tmp404/1W & \leftarrow < \, - & temperature/3I, const\_42\_4/3C  \\\hline
# tmp440/1W & \leftarrow > \, - & temperature/3I, tmp439/3W  \\\hline
# tmp267/1W & \leftarrow < \, - & temperature/3I, const\_31\_4/3C  \\\hline
# tmp695/1W & \leftarrow \, = \, - & state\_water/3R, const\_15\_5/3C  \\\hline
# tmp90/1W & \leftarrow \, = \, - & state\_water/3R, const\_15\_5/3C  \\\hline
# tmp236/1W & \leftarrow > \, - & temperature/3I, const\_30\_5/3C  \\\hline
# tmp496/3W & \leftarrow c \, - & tmp495/1W, const\_50\_2/2C  \\\hline
# tmp172/1W & \leftarrow s \, - & const\_24\_0/1C ((0,)) \\\hline
# tmp434/1W & \leftarrow \sim \, - & tmp404/1W  \\\hline
# tmp102/1W & \leftarrow s \, - & const\_19\_0/1C ((0,)) \\\hline
# tmp546/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_13\_3/3C  \\\hline
# tmp266/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_13\_3/3C  \\\hline
# tmp697/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_13\_3/3C  \\\hline
# tmp701/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_14\_4/3C  \\\hline
# tmp437/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_14\_4/3C  \\\hline
# tmp83/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_11\_1/3C  \\\hline
# tmp141/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_13\_3/3C  \\\hline
# tmp584/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_14\_4/3C  \\\hline
# tmp403/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_13\_3/3C  \\\hline
# tmp171/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_14\_4/3C  \\\hline
# tmp72/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_10\_0/3C  \\\hline
# tmp300/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_14\_4/3C  \\\hline
# tmp373/1W & \leftarrow > \, - & temperature/3I, const\_41\_5/3C  \\\hline
# tmp547/1W & \leftarrow < \, - & temperature/3I, const\_53\_4/3C  \\\hline
# tmp139/1W & \leftarrow \sim \, - & tmp115/1W  \\\hline
# tmp512/1W & \leftarrow > \, - & temperature/3I, const\_52\_5/3C  \\\hline
# tmp357/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_12\_2/3C  \\\hline
# tmp494/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_12\_2/3C  \\\hline
# tmp101/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_12\_2/3C  \\\hline
# tmp220/1W & \leftarrow \, = \, - & state\_temperature/3R, const\_12\_2/3C  \\\hline
# tmp405/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp304/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp347/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp78/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp548/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp93/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp324/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp143/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp268/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp421/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp251/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp237/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp461/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp210/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp640/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp441/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp361/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp388/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp374/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp482/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp566/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp529/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp588/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp513/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp193/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp175/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp610/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp116/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp157/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp66/1W & \leftarrow \& \, - & start/1I, reset/1I  \\\hline
# tmp84/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp73/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp69/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp105/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp224/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp67/1W & \leftarrow \& \, - & start/1I, reset/1I  \\\hline
# tmp630/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp284/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp128/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp498/1W & \leftarrow \sim \, - & reset/1I  \\\hline
# tmp320/1W & \leftarrow s \, - & const\_36\_0/1C ((0,)) \\\hline
# tmp209/1W & \leftarrow > \, - & water/4I, const\_27\_14/4C  \\\hline
# tmp481/1W & \leftarrow > \, - & water/4I, tmp480/4W  \\\hline
# tmp91/1W & \leftarrow > \, - & water/4I, const\_17\_14/4C  \\\hline
# tmp94/1W & \leftarrow \& \, - & start/1I, tmp93/1W  \\\hline
# tmp631/1W & \leftarrow \& \, - & start/1I, tmp630/1W  \\\hline
# tmp305/1W & \leftarrow \& \, - & start/1I, tmp304/1W  \\\hline
# tmp144/1W & \leftarrow \& \, - & start/1I, tmp143/1W  \\\hline
# tmp530/1W & \leftarrow \& \, - & start/1I, tmp529/1W  \\\hline
# tmp194/1W & \leftarrow \& \, - & start/1I, tmp193/1W  \\\hline
# tmp661/3W & \leftarrow x \, - & tmp67/1W, state\_temperature/3R, const\_11\_1/3C  \\\hline
# tmp270/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp239/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp463/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp212/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp363/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp484/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp568/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp515/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp195/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp177/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp326/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp376/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp642/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp612/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp443/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp159/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp130/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp86/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp118/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp80/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp107/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp632/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp226/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp390/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp145/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp500/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp286/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp590/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp253/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp407/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp306/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp349/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp423/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp531/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp550/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp95/1W & \leftarrow \sim \, - & tmp68/1W  \\\hline
# tmp589/1W & \leftarrow \& \, - & start/1I, tmp588/1W  \\\hline
# tmp638/1W & \leftarrow \sim \, - & tmp342/1W  \\\hline
# tmp648/1W & \leftarrow \sim \, - & tmp342/1W  \\\hline
# tmp334/1W & \leftarrow \sim \, - & tmp220/1W  \\\hline
# tmp294/1W & \leftarrow \sim \, - & tmp220/1W  \\\hline
# tmp278/1W & \leftarrow \sim \, - & tmp220/1W  \\\hline
# tmp314/1W & \leftarrow \sim \, - & tmp220/1W  \\\hline
# tmp422/1W & \leftarrow \& \, - & start/1I, tmp421/1W  \\\hline
# tmp336/1W & \leftarrow \sim \, - & tmp266/1W  \\\hline
# tmp316/1W & \leftarrow \sim \, - & tmp266/1W  \\\hline
# tmp129/1W & \leftarrow \& \, - & start/1I, tmp128/1W  \\\hline
# tmp297/1W & \leftarrow \sim \, - & tmp267/1W  \\\hline
# tmp103/3W & \leftarrow c \, - & tmp102/1W, const\_18\_2/2C  \\\hline
# tmp703/4W & \leftarrow c \, - & tmp702/3W, tmp701/1W  \\\hline
# tmp514/1W & \leftarrow \& \, - & start/1I, tmp513/1W  \\\hline
# tmp79/1W & \leftarrow \& \, - & start/1I, tmp78/1W  \\\hline
# tmp168/1W & \leftarrow \sim \, - & tmp142/1W  \\\hline
# tmp473/1W & \leftarrow \sim \, - & tmp403/1W  \\\hline
# tmp453/1W & \leftarrow \sim \, - & tmp403/1W  \\\hline
# tmp476/1W & \leftarrow \sim \, - & tmp440/1W  \\\hline
# tmp285/1W & \leftarrow \& \, - & start/1I, tmp284/1W  \\\hline
# tmp264/1W & \leftarrow \sim \, - & tmp236/1W  \\\hline
# tmp321/3W & \leftarrow c \, - & tmp320/1W, const\_35\_3/2C  \\\hline
# tmp401/1W & \leftarrow \sim \, - & tmp373/1W  \\\hline
# tmp544/1W & \leftarrow \sim \, - & tmp512/1W  \\\hline
# tmp106/1W & \leftarrow \& \, - & start/1I, tmp105/1W  \\\hline
# tmp627/1W & \leftarrow \sim \, - & tmp587/1W  \\\hline
# tmp581/1W & \leftarrow \sim \, - & tmp547/1W  \\\hline
# tmp641/1W & \leftarrow \& \, - & start/1I, tmp640/1W  \\\hline
# tmp578/1W & \leftarrow \sim \, - & tmp494/1W  \\\hline
# tmp622/1W & \leftarrow \sim \, - & tmp494/1W  \\\hline
# tmp600/1W & \leftarrow \sim \, - & tmp494/1W  \\\hline
# tmp560/1W & \leftarrow \sim \, - & tmp494/1W  \\\hline
# tmp201/1W & \leftarrow \sim \, - & tmp101/1W  \\\hline
# tmp183/1W & \leftarrow \sim \, - & tmp101/1W  \\\hline
# tmp165/1W & \leftarrow \sim \, - & tmp101/1W  \\\hline
# tmp151/1W & \leftarrow \sim \, - & tmp101/1W  \\\hline
# tmp345/1W & \leftarrow > \, - & water/4I, tmp344/4W  \\\hline
# tmp225/1W & \leftarrow \& \, - & start/1I, tmp224/1W  \\\hline
# tmp158/1W & \leftarrow \& \, - & start/1I, tmp157/1W  \\\hline
# tmp362/1W & \leftarrow \& \, - & start/1I, tmp361/1W  \\\hline
# tmp301/1W & \leftarrow s \, - & const\_34\_0/1C ((0,)) \\\hline
# tmp607/3W & \leftarrow c \, - & tmp606/1W, const\_57\_3/2C  \\\hline
# tmp348/1W & \leftarrow \& \, - & start/1I, tmp347/1W  \\\hline
# tmp190/3W & \leftarrow c \, - & tmp189/1W, const\_25\_3/2C  \\\hline
# tmp565/1W & \leftarrow \sim \, - & tmp564/1W  \\\hline
# tmp203/1W & \leftarrow \sim \, - & tmp141/1W  \\\hline
# tmp185/1W & \leftarrow \sim \, - & tmp141/1W  \\\hline
# tmp499/1W & \leftarrow \& \, - & start/1I, tmp498/1W  \\\hline
# tmp346/1W & \leftarrow \sim \, - & tmp345/1W  \\\hline
# tmp602/1W & \leftarrow \sim \, - & tmp546/1W  \\\hline
# tmp624/1W & \leftarrow \sim \, - & tmp546/1W  \\\hline
# tmp74/1W & \leftarrow \& \, - & start/1I, tmp73/1W  \\\hline
# tmp699/2W & \leftarrow c \, - & tmp698/1W, tmp697/1W  \\\hline
# tmp211/1W & \leftarrow \& \, - & start/1I, tmp210/1W  \\\hline
# tmp611/1W & \leftarrow \& \, - & start/1I, tmp610/1W  \\\hline
# tmp104/1W & \leftarrow < \, - & temperature/3I, tmp103/3W  \\\hline
# tmp322/1W & \leftarrow > \, - & temperature/3I, tmp321/3W  \\\hline
# tmp501/1W & \leftarrow \& \, - & tmp499/1W, tmp500/1W  \\\hline
# tmp283/1W & \leftarrow \sim \, - & tmp282/1W  \\\hline
# tmp262/1W & \leftarrow \sim \, - & tmp223/1W  \\\hline
# tmp248/1W & \leftarrow \sim \, - & tmp223/1W  \\\hline
# tmp173/3W & \leftarrow c \, - & tmp172/1W, const\_23\_3/2C  \\\hline
# tmp549/1W & \leftarrow \& \, - & start/1I, tmp548/1W  \\\hline
# tmp420/1W & \leftarrow \sim \, - & tmp419/1W  \\\hline
# tmp385/1W & \leftarrow \sim \, - & tmp360/1W  \\\hline
# tmp399/1W & \leftarrow \sim \, - & tmp360/1W  \\\hline
# tmp92/1W & \leftarrow \sim \, - & tmp91/1W  \\\hline
# tmp460/1W & \leftarrow \sim \, - & tmp459/1W  \\\hline
# tmp353/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp447/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp427/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp467/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp519/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp554/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp572/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp380/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp646/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp367/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp488/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp394/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp636/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp504/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp411/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp616/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp535/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp594/1W & \leftarrow \sim \, - & tmp90/1W  \\\hline
# tmp567/1W & \leftarrow \& \, - & start/1I, tmp566/1W  \\\hline
# tmp633/1W & \leftarrow \& \, - & tmp631/1W, tmp632/1W  \\\hline
# tmp96/1W & \leftarrow \& \, - & tmp94/1W, tmp95/1W  \\\hline
# tmp497/1W & \leftarrow < \, - & temperature/3I, tmp496/3W  \\\hline
# tmp325/1W & \leftarrow \& \, - & start/1I, tmp324/1W  \\\hline
# tmp70/1W & \leftarrow \& \, - & start/1I, tmp69/1W  \\\hline
# tmp196/1W & \leftarrow \& \, - & tmp194/1W, tmp195/1W  \\\hline
# tmp146/1W & \leftarrow \& \, - & tmp144/1W, tmp145/1W  \\\hline
# tmp307/1W & \leftarrow \& \, - & tmp305/1W, tmp306/1W  \\\hline
# tmp302/3W & \leftarrow c \, - & tmp301/1W, const\_33\_3/2C  \\\hline
# tmp238/1W & \leftarrow \& \, - & start/1I, tmp237/1W  \\\hline
# tmp462/1W & \leftarrow \& \, - & start/1I, tmp461/1W  \\\hline
# tmp176/1W & \leftarrow \& \, - & start/1I, tmp175/1W  \\\hline
# tmp108/1W & \leftarrow \& \, - & tmp106/1W, tmp107/1W  \\\hline
# tmp156/1W & \leftarrow \sim \, - & tmp155/1W  \\\hline
# tmp252/1W & \leftarrow \& \, - & start/1I, tmp251/1W  \\\hline
# tmp375/1W & \leftarrow \& \, - & start/1I, tmp374/1W  \\\hline
# tmp619/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp507/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp538/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp597/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp522/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp557/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp575/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp491/1W & \leftarrow \sim \, - & tmp346/1W  \\\hline
# tmp700/4W & \leftarrow * \, - & tmp699/2W, const\_59\_3/2C  \\\hline
# tmp327/1W & \leftarrow \& \, - & tmp325/1W, tmp326/1W  \\\hline
# tmp269/1W & \leftarrow \& \, - & start/1I, tmp268/1W  \\\hline
# tmp389/1W & \leftarrow \& \, - & start/1I, tmp388/1W  \\\hline
# tmp483/1W & \leftarrow \& \, - & start/1I, tmp482/1W  \\\hline
# tmp532/1W & \leftarrow \& \, - & tmp530/1W, tmp531/1W  \\\hline
# tmp643/1W & \leftarrow \& \, - & tmp641/1W, tmp642/1W  \\\hline
# tmp406/1W & \leftarrow \& \, - & start/1I, tmp405/1W  \\\hline
# tmp117/1W & \leftarrow \& \, - & start/1I, tmp116/1W  \\\hline
# tmp191/1W & \leftarrow > \, - & temperature/3I, tmp190/3W  \\\hline
# tmp85/1W & \leftarrow \& \, - & start/1I, tmp84/1W  \\\hline
# tmp442/1W & \leftarrow \& \, - & start/1I, tmp441/1W  \\\hline
# tmp415/1W & \leftarrow \sim \, - & tmp357/1W  \\\hline
# tmp451/1W & \leftarrow \sim \, - & tmp357/1W  \\\hline
# tmp431/1W & \leftarrow \sim \, - & tmp357/1W  \\\hline
# tmp471/1W & \leftarrow \sim \, - & tmp357/1W  \\\hline
# tmp591/1W & \leftarrow \& \, - & tmp589/1W, tmp590/1W  \\\hline
# tmp227/1W & \leftarrow \& \, - & tmp225/1W, tmp226/1W  \\\hline
# tmp696/1W & \leftarrow \| \, - & tmp694/1W, tmp695/1W  \\\hline
# tmp652/3W & \leftarrow x \, - & tmp66/1W, state\_water/3R, const\_11\_1/3C  \\\hline
# tmp516/1W & \leftarrow \& \, - & tmp514/1W, tmp515/1W  \\\hline
# tmp160/1W & \leftarrow \& \, - & tmp158/1W, tmp159/1W  \\\hline
# tmp364/1W & \leftarrow \& \, - & tmp362/1W, tmp363/1W  \\\hline
# tmp350/1W & \leftarrow \& \, - & tmp348/1W, tmp349/1W  \\\hline
# tmp287/1W & \leftarrow \& \, - & tmp285/1W, tmp286/1W  \\\hline
# tmp131/1W & \leftarrow \& \, - & tmp129/1W, tmp130/1W  \\\hline
# tmp424/1W & \leftarrow \& \, - & tmp422/1W, tmp423/1W  \\\hline
# tmp329/1W & \leftarrow \& \, - & tmp327/1W, tmp328/1W  \\\hline
# tmp81/1W & \leftarrow \& \, - & tmp79/1W, tmp80/1W  \\\hline
# tmp213/1W & \leftarrow \& \, - & tmp211/1W, tmp212/1W  \\\hline
# tmp613/1W & \leftarrow \& \, - & tmp611/1W, tmp612/1W  \\\hline
# tmp503/1W & \leftarrow \& \, - & tmp501/1W, tmp502/1W  \\\hline
# tmp174/1W & \leftarrow > \, - & temperature/3I, tmp173/3W  \\\hline
# tmp229/1W & \leftarrow \& \, - & tmp227/1W, tmp228/1W  \\\hline
# tmp162/1W & \leftarrow \& \, - & tmp160/1W, tmp161/1W  \\\hline
# tmp323/1W & \leftarrow \sim \, - & tmp322/1W  \\\hline
# tmp635/1W & \leftarrow \& \, - & tmp633/1W, tmp634/1W  \\\hline
# tmp98/1W & \leftarrow \& \, - & tmp96/1W, tmp97/1W  \\\hline
# tmp198/1W & \leftarrow \& \, - & tmp196/1W, tmp197/1W  \\\hline
# tmp148/1W & \leftarrow \& \, - & tmp146/1W, tmp147/1W  \\\hline
# tmp309/1W & \leftarrow \& \, - & tmp307/1W, tmp308/1W  \\\hline
# tmp303/1W & \leftarrow > \, - & temperature/3I, tmp302/3W  \\\hline
# tmp75/1W & \leftarrow \& \, - & tmp74/1W, tmp68/1W  \\\hline
# tmp551/1W & \leftarrow \& \, - & tmp549/1W, tmp550/1W  \\\hline
# tmp569/1W & \leftarrow \& \, - & tmp567/1W, tmp568/1W  \\\hline
# tmp637/1W & \leftarrow \& \, - & tmp635/1W, tmp636/1W  \\\hline
# tmp240/1W & \leftarrow \& \, - & tmp238/1W, tmp239/1W  \\\hline
# tmp464/1W & \leftarrow \& \, - & tmp462/1W, tmp463/1W  \\\hline
# tmp178/1W & \leftarrow \& \, - & tmp176/1W, tmp177/1W  \\\hline
# tmp377/1W & \leftarrow \& \, - & tmp375/1W, tmp376/1W  \\\hline
# tmp593/1W & \leftarrow \& \, - & tmp591/1W, tmp592/1W  \\\hline
# tmp339/1W & \leftarrow \sim \, - & tmp303/1W  \\\hline
# tmp291/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp311/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp258/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp275/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp217/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp231/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp331/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp244/1W & \leftarrow \sim \, - & tmp92/1W  \\\hline
# tmp408/1W & \leftarrow \& \, - & tmp406/1W, tmp407/1W  \\\hline
# tmp119/1W & \leftarrow \& \, - & tmp117/1W, tmp118/1W  \\\hline
# tmp289/1W & \leftarrow \& \, - & tmp287/1W, tmp288/1W  \\\hline
# tmp163/1W & \leftarrow \& \, - & tmp162/1W, tmp90/1W  \\\hline
# tmp87/1W & \leftarrow \& \, - & tmp85/1W, tmp86/1W  \\\hline
# tmp444/1W & \leftarrow \& \, - & tmp442/1W, tmp443/1W  \\\hline
# tmp426/1W & \leftarrow \& \, - & tmp424/1W, tmp425/1W  \\\hline
# tmp164/1W & \leftarrow \& \, - & tmp163/1W, tmp92/1W  \\\hline
# tmp137/1W & \leftarrow \sim \, - & tmp104/1W  \\\hline
# tmp125/1W & \leftarrow \sim \, - & tmp104/1W  \\\hline
# tmp615/1W & \leftarrow \& \, - & tmp613/1W, tmp614/1W  \\\hline
# tmp639/1W & \leftarrow \& \, - & tmp637/1W, tmp638/1W  \\\hline
# tmp110/1W & \leftarrow \& \, - & tmp108/1W, tmp109/1W  \\\hline
# tmp608/1W & \leftarrow > \, - & temperature/3I, tmp607/3W  \\\hline
# tmp617/1W & \leftarrow \& \, - & tmp615/1W, tmp616/1W  \\\hline
# tmp534/1W & \leftarrow \& \, - & tmp532/1W, tmp533/1W  \\\hline
# tmp645/1W & \leftarrow \& \, - & tmp643/1W, tmp644/1W  \\\hline
# tmp192/1W & \leftarrow \sim \, - & tmp191/1W  \\\hline
# tmp366/1W & \leftarrow \& \, - & tmp364/1W, tmp365/1W  \\\hline
# tmp71/1W & \leftarrow \& \, - & tmp70/1W, tmp68/1W  \\\hline
# tmp133/1W & \leftarrow \& \, - & tmp131/1W, tmp132/1W  \\\hline
# tmp254/1W & \leftarrow \& \, - & tmp252/1W, tmp253/1W  \\\hline
# tmp330/1W & \leftarrow \& \, - & tmp329/1W, tmp90/1W  \\\hline
# tmp391/1W & \leftarrow \& \, - & tmp389/1W, tmp390/1W  \\\hline
# tmp215/1W & \leftarrow \& \, - & tmp213/1W, tmp214/1W  \\\hline
# tmp526/1W & \leftarrow \sim \, - & tmp497/1W  \\\hline
# tmp542/1W & \leftarrow \sim \, - & tmp497/1W  \\\hline
# tmp99/1W & \leftarrow \& \, - & tmp98/1W, tmp90/1W  \\\hline
# tmp704/5W & \leftarrow + \, - & tmp700/4W, tmp703/4W  \\\hline
# tmp199/1W & \leftarrow \& \, - & tmp198/1W, tmp90/1W  \\\hline
# tmp149/1W & \leftarrow \& \, - & tmp148/1W, tmp90/1W  \\\hline
# tmp310/1W & \leftarrow \& \, - & tmp309/1W, tmp90/1W  \\\hline
# tmp553/1W & \leftarrow \& \, - & tmp551/1W, tmp552/1W  \\\hline
# tmp571/1W & \leftarrow \& \, - & tmp569/1W, tmp570/1W  \\\hline
# tmp166/1W & \leftarrow \& \, - & tmp164/1W, tmp165/1W  \\\hline
# tmp609/1W & \leftarrow \sim \, - & tmp608/1W  \\\hline
# tmp180/1W & \leftarrow \& \, - & tmp178/1W, tmp179/1W  \\\hline
# tmp653/3W & \leftarrow x \, - & tmp71/1W, tmp652/3W, const\_11\_1/3C  \\\hline
# tmp76/1W & \leftarrow \& \, - & tmp75/1W, tmp72/1W  \\\hline
# tmp242/1W & \leftarrow \& \, - & tmp240/1W, tmp241/1W  \\\hline
# tmp466/1W & \leftarrow \& \, - & tmp464/1W, tmp465/1W  \\\hline
# tmp200/1W & \leftarrow \& \, - & tmp199/1W, tmp92/1W  \\\hline
# tmp150/1W & \leftarrow \& \, - & tmp149/1W, tmp92/1W  \\\hline
# tmp379/1W & \leftarrow \& \, - & tmp377/1W, tmp378/1W  \\\hline
# tmp410/1W & \leftarrow \& \, - & tmp408/1W, tmp409/1W  \\\hline
# tmp121/1W & \leftarrow \& \, - & tmp119/1W, tmp120/1W  \\\hline
# tmp290/1W & \leftarrow \& \, - & tmp289/1W, tmp90/1W  \\\hline
# tmp332/1W & \leftarrow \& \, - & tmp330/1W, tmp331/1W  \\\hline
# tmp88/1W & \leftarrow \& \, - & tmp87/1W, tmp77/1W  \\\hline
# tmp446/1W & \leftarrow \& \, - & tmp444/1W, tmp445/1W  \\\hline
# tmp206/1W & \leftarrow \sim \, - & tmp174/1W  \\\hline
# tmp505/1W & \leftarrow \& \, - & tmp503/1W, tmp504/1W  \\\hline
# tmp111/1W & \leftarrow \& \, - & tmp110/1W, tmp90/1W  \\\hline
# tmp618/1W & \leftarrow \& \, - & tmp617/1W, tmp342/1W  \\\hline
# tmp292/1W & \leftarrow \& \, - & tmp290/1W, tmp291/1W  \\\hline
# tmp312/1W & \leftarrow \& \, - & tmp310/1W, tmp311/1W  \\\hline
# tmp536/1W & \leftarrow \& \, - & tmp534/1W, tmp535/1W  \\\hline
# tmp647/1W & \leftarrow \& \, - & tmp645/1W, tmp646/1W  \\\hline
# tmp82/1W & \leftarrow \& \, - & tmp81/1W, tmp77/1W  \\\hline
# tmp230/1W & \leftarrow \& \, - & tmp229/1W, tmp90/1W  \\\hline
# tmp595/1W & \leftarrow \& \, - & tmp593/1W, tmp594/1W  \\\hline
# pump/1O & \leftarrow w \, - & tmp696/1W  \\\hline
# tmp112/1W & \leftarrow \& \, - & tmp111/1W, tmp92/1W  \\\hline
# tmp368/1W & \leftarrow \& \, - & tmp366/1W, tmp367/1W  \\\hline
# tmp202/1W & \leftarrow \& \, - & tmp200/1W, tmp201/1W  \\\hline
# tmp152/1W & \leftarrow \& \, - & tmp150/1W, tmp151/1W  \\\hline
# tmp134/1W & \leftarrow \& \, - & tmp133/1W, tmp90/1W  \\\hline
# tmp518/1W & \leftarrow \& \, - & tmp516/1W, tmp517/1W  \\\hline
# tmp352/1W & \leftarrow \& \, - & tmp350/1W, tmp351/1W  \\\hline
# tmp485/1W & \leftarrow \& \, - & tmp483/1W, tmp484/1W  \\\hline
# tmp428/1W & \leftarrow \& \, - & tmp426/1W, tmp427/1W  \\\hline
# tmp271/1W & \leftarrow \& \, - & tmp269/1W, tmp270/1W  \\\hline
# tmp256/1W & \leftarrow \& \, - & tmp254/1W, tmp255/1W  \\\hline
# tmp393/1W & \leftarrow \& \, - & tmp391/1W, tmp392/1W  \\\hline
# tmp216/1W & \leftarrow \& \, - & tmp215/1W, tmp90/1W  \\\hline
# tmp232/1W & \leftarrow \& \, - & tmp230/1W, tmp231/1W  \\\hline
# tmp354/1W & \leftarrow \& \, - & tmp352/1W, tmp353/1W  \\\hline
# tmp122/1W & \leftarrow \& \, - & tmp121/1W, tmp90/1W  \\\hline
# tmp448/1W & \leftarrow \& \, - & tmp446/1W, tmp447/1W  \\\hline
# tmp135/1W & \leftarrow \& \, - & tmp134/1W, tmp92/1W  \\\hline
# tmp705/2W & \leftarrow s \, - & tmp704/5W ((0, 1)) \\\hline
# tmp555/1W & \leftarrow \& \, - & tmp553/1W, tmp554/1W  \\\hline
# tmp620/1W & \leftarrow \& \, - & tmp618/1W, tmp619/1W  \\\hline
# tmp449/1W & \leftarrow \& \, - & tmp448/1W, tmp342/1W  \\\hline
# tmp573/1W & \leftarrow \& \, - & tmp571/1W, tmp572/1W  \\\hline
# tmp181/1W & \leftarrow \& \, - & tmp180/1W, tmp90/1W  \\\hline
# tmp243/1W & \leftarrow \& \, - & tmp242/1W, tmp90/1W  \\\hline
# tmp468/1W & \leftarrow \& \, - & tmp466/1W, tmp467/1W  \\\hline
# tmp113/1W & \leftarrow \& \, - & tmp112/1W, tmp101/1W  \\\hline
# tmp100/1W & \leftarrow \& \, - & tmp99/1W, tmp92/1W  \\\hline
# tmp381/1W & \leftarrow \& \, - & tmp379/1W, tmp380/1W  \\\hline
# tmp333/1W & \leftarrow \& \, - & tmp332/1W, tmp209/1W  \\\hline
# tmp654/3W & \leftarrow x \, - & tmp82/1W, tmp653/3W, const\_15\_5/3C  \\\hline
# tmp596/1W & \leftarrow \& \, - & tmp595/1W, tmp342/1W  \\\hline
# tmp412/1W & \leftarrow \& \, - & tmp410/1W, tmp411/1W  \\\hline
# tmp429/1W & \leftarrow \& \, - & tmp428/1W, tmp342/1W  \\\hline
# tmp182/1W & \leftarrow \& \, - & tmp181/1W, tmp92/1W  \\\hline
# tmp245/1W & \leftarrow \& \, - & tmp243/1W, tmp244/1W  \\\hline
# tmp313/1W & \leftarrow \& \, - & tmp312/1W, tmp209/1W  \\\hline
# tmp506/1W & \leftarrow \& \, - & tmp505/1W, tmp342/1W  \\\hline
# tmp136/1W & \leftarrow \& \, - & tmp135/1W, tmp101/1W  \\\hline
# tmp167/1W & \leftarrow \& \, - & tmp166/1W, tmp141/1W  \\\hline
# tmp662/3W & \leftarrow x \, - & tmp76/1W, tmp661/3W, const\_11\_1/3C  \\\hline
# tmp123/1W & \leftarrow \& \, - & tmp122/1W, tmp92/1W  \\\hline
# tmp89/1W & \leftarrow \& \, - & tmp88/1W, tmp83/1W  \\\hline
# tmp537/1W & \leftarrow \& \, - & tmp536/1W, tmp342/1W  \\\hline
# tmp649/1W & \leftarrow \& \, - & tmp647/1W, tmp648/1W  \\\hline
# tmp218/1W & \leftarrow \& \, - & tmp216/1W, tmp217/1W  \\\hline
# tmp450/1W & \leftarrow \& \, - & tmp449/1W, tmp346/1W  \\\hline
# tmp114/1W & \leftarrow \& \, - & tmp113/1W, tmp104/1W  \\\hline
# tmp153/1W & \leftarrow \& \, - & tmp152/1W, tmp141/1W  \\\hline
# tmp369/1W & \leftarrow \& \, - & tmp368/1W, tmp342/1W  \\\hline
# tmp293/1W & \leftarrow \& \, - & tmp292/1W, tmp209/1W  \\\hline
# tmp598/1W & \leftarrow \& \, - & tmp596/1W, tmp597/1W  \\\hline
# tmp452/1W & \leftarrow \& \, - & tmp450/1W, tmp451/1W  \\\hline
# tmp487/1W & \leftarrow \& \, - & tmp485/1W, tmp486/1W  \\\hline
# tmp273/1W & \leftarrow \& \, - & tmp271/1W, tmp272/1W  \\\hline
# tmp204/1W & \leftarrow \& \, - & tmp202/1W, tmp203/1W  \\\hline
# tmp395/1W & \leftarrow \& \, - & tmp393/1W, tmp394/1W  \\\hline
# tmp124/1W & \leftarrow \& \, - & tmp123/1W, tmp101/1W  \\\hline
# tmp355/1W & \leftarrow \& \, - & tmp354/1W, tmp342/1W  \\\hline
# tmp430/1W & \leftarrow \& \, - & tmp429/1W, tmp346/1W  \\\hline
# tmp184/1W & \leftarrow \& \, - & tmp182/1W, tmp183/1W  \\\hline
# tmp138/1W & \leftarrow \& \, - & tmp136/1W, tmp137/1W  \\\hline
# tmp621/1W & \leftarrow \& \, - & tmp620/1W, tmp481/1W  \\\hline
# tmp520/1W & \leftarrow \& \, - & tmp518/1W, tmp519/1W  \\\hline
# tmp257/1W & \leftarrow \& \, - & tmp256/1W, tmp90/1W  \\\hline
# tmp356/1W & \leftarrow \& \, - & tmp355/1W, tmp346/1W  \\\hline
# tmp259/1W & \leftarrow \& \, - & tmp257/1W, tmp258/1W  \\\hline
# tmp556/1W & \leftarrow \& \, - & tmp555/1W, tmp342/1W  \\\hline
# tmp335/1W & \leftarrow \& \, - & tmp333/1W, tmp334/1W  \\\hline
# tmp574/1W & \leftarrow \& \, - & tmp573/1W, tmp342/1W  \\\hline
# tmp432/1W & \leftarrow \& \, - & tmp430/1W, tmp431/1W  \\\hline
# tmp469/1W & \leftarrow \& \, - & tmp468/1W, tmp342/1W  \\\hline
# tmp655/3W & \leftarrow x \, - & tmp100/1W, tmp654/3W, const\_15\_5/3C  \\\hline
# tmp370/1W & \leftarrow \& \, - & tmp369/1W, tmp346/1W  \\\hline
# tmp382/1W & \leftarrow \& \, - & tmp381/1W, tmp342/1W  \\\hline
# tmp315/1W & \leftarrow \& \, - & tmp313/1W, tmp314/1W  \\\hline
# tmp233/1W & \leftarrow \& \, - & tmp232/1W, tmp209/1W  \\\hline
# tmp539/1W & \leftarrow \& \, - & tmp537/1W, tmp538/1W  \\\hline
# tmp219/1W & \leftarrow \& \, - & tmp218/1W, tmp209/1W  \\\hline
# tmp126/1W & \leftarrow \& \, - & tmp124/1W, tmp125/1W  \\\hline
# tmp140/1W & \leftarrow \& \, - & tmp138/1W, tmp139/1W  \\\hline
# ac/2O & \leftarrow w \, - & tmp705/2W  \\\hline
# tmp413/1W & \leftarrow \& \, - & tmp412/1W, tmp342/1W  \\\hline
# tmp169/1W & \leftarrow \& \, - & tmp167/1W, tmp168/1W  \\\hline
# tmp371/1W & \leftarrow \& \, - & tmp370/1W, tmp357/1W  \\\hline
# tmp433/1W & \leftarrow \& \, - & tmp432/1W, tmp403/1W  \\\hline
# tmp508/1W & \leftarrow \& \, - & tmp506/1W, tmp507/1W  \\\hline
# tmp154/1W & \leftarrow \& \, - & tmp153/1W, tmp142/1W  \\\hline
# tmp435/1W & \leftarrow \& \, - & tmp433/1W, tmp434/1W  \\\hline
# tmp127/1W & \leftarrow \& \, - & tmp126/1W, tmp115/1W  \\\hline
# tmp295/1W & \leftarrow \& \, - & tmp293/1W, tmp294/1W  \\\hline
# tmp246/1W & \leftarrow \& \, - & tmp245/1W, tmp209/1W  \\\hline
# tmp663/3W & \leftarrow x \, - & tmp89/1W, tmp662/3W, const\_12\_2/3C  \\\hline
# tmp599/1W & \leftarrow \& \, - & tmp598/1W, tmp481/1W  \\\hline
# tmp337/1W & \leftarrow \& \, - & tmp335/1W, tmp336/1W  \\\hline
# tmp623/1W & \leftarrow \& \, - & tmp621/1W, tmp622/1W  \\\hline
# tmp558/1W & \leftarrow \& \, - & tmp556/1W, tmp557/1W  \\\hline
# tmp489/1W & \leftarrow \& \, - & tmp487/1W, tmp488/1W  \\\hline
# tmp274/1W & \leftarrow \& \, - & tmp273/1W, tmp90/1W  \\\hline
# tmp576/1W & \leftarrow \& \, - & tmp574/1W, tmp575/1W  \\\hline
# tmp205/1W & \leftarrow \& \, - & tmp204/1W, tmp171/1W  \\\hline
# tmp396/1W & \leftarrow \& \, - & tmp395/1W, tmp342/1W  \\\hline
# tmp317/1W & \leftarrow \& \, - & tmp315/1W, tmp316/1W  \\\hline
# tmp454/1W & \leftarrow \& \, - & tmp452/1W, tmp453/1W  \\\hline
# tmp470/1W & \leftarrow \& \, - & tmp469/1W, tmp346/1W  \\\hline
# tmp509/1W & \leftarrow \& \, - & tmp508/1W, tmp481/1W  \\\hline
# tmp383/1W & \leftarrow \& \, - & tmp382/1W, tmp346/1W  \\\hline
# tmp170/1W & \leftarrow \& \, - & tmp169/1W, tmp156/1W  \\\hline
# tmp384/1W & \leftarrow \& \, - & tmp383/1W, tmp357/1W  \\\hline
# tmp521/1W & \leftarrow \& \, - & tmp520/1W, tmp342/1W  \\\hline
# tmp540/1W & \leftarrow \& \, - & tmp539/1W, tmp481/1W  \\\hline
# tmp372/1W & \leftarrow \& \, - & tmp371/1W, tmp360/1W  \\\hline
# tmp276/1W & \leftarrow \& \, - & tmp274/1W, tmp275/1W  \\\hline
# tmp414/1W & \leftarrow \& \, - & tmp413/1W, tmp346/1W  \\\hline
# tmp416/1W & \leftarrow \& \, - & tmp414/1W, tmp415/1W  \\\hline
# tmp234/1W & \leftarrow \& \, - & tmp233/1W, tmp220/1W  \\\hline
# tmp472/1W & \leftarrow \& \, - & tmp470/1W, tmp471/1W  \\\hline
# tmp436/1W & \leftarrow \& \, - & tmp435/1W, tmp420/1W  \\\hline
# tmp296/1W & \leftarrow \& \, - & tmp295/1W, tmp266/1W  \\\hline
# tmp186/1W & \leftarrow \& \, - & tmp184/1W, tmp185/1W  \\\hline
# tmp625/1W & \leftarrow \& \, - & tmp623/1W, tmp624/1W  \\\hline
# tmp386/1W & \leftarrow \& \, - & tmp384/1W, tmp385/1W  \\\hline
# tmp260/1W & \leftarrow \& \, - & tmp259/1W, tmp209/1W  \\\hline
# tmp656/3W & \leftarrow x \, - & tmp219/1W, tmp655/3W, const\_16\_6/3C  \\\hline
# tmp601/1W & \leftarrow \& \, - & tmp599/1W, tmp600/1W  \\\hline
# tmp559/1W & \leftarrow \& \, - & tmp558/1W, tmp481/1W  \\\hline
# tmp577/1W & \leftarrow \& \, - & tmp576/1W, tmp481/1W  \\\hline
# tmp523/1W & \leftarrow \& \, - & tmp521/1W, tmp522/1W  \\\hline
# tmp397/1W & \leftarrow \& \, - & tmp396/1W, tmp346/1W  \\\hline
# tmp398/1W & \leftarrow \& \, - & tmp397/1W, tmp357/1W  \\\hline
# tmp338/1W & \leftarrow \& \, - & tmp337/1W, tmp300/1W  \\\hline
# tmp318/1W & \leftarrow \& \, - & tmp317/1W, tmp300/1W  \\\hline
# tmp510/1W & \leftarrow \& \, - & tmp509/1W, tmp494/1W  \\\hline
# tmp400/1W & \leftarrow \& \, - & tmp398/1W, tmp399/1W  \\\hline
# tmp490/1W & \leftarrow \& \, - & tmp489/1W, tmp342/1W  \\\hline
# tmp541/1W & \leftarrow \& \, - & tmp540/1W, tmp494/1W  \\\hline
# tmp402/1W & \leftarrow \& \, - & tmp400/1W, tmp401/1W  \\\hline
# tmp247/1W & \leftarrow \& \, - & tmp246/1W, tmp220/1W  \\\hline
# tmp455/1W & \leftarrow \& \, - & tmp454/1W, tmp437/1W  \\\hline
# tmp664/3W & \leftarrow x \, - & tmp114/1W, tmp663/3W, const\_13\_3/3C  \\\hline
# tmp298/1W & \leftarrow \& \, - & tmp296/1W, tmp297/1W  \\\hline
# tmp492/1W & \leftarrow \& \, - & tmp490/1W, tmp491/1W  \\\hline
# tmp207/1W & \leftarrow \& \, - & tmp205/1W, tmp206/1W  \\\hline
# tmp417/1W & \leftarrow \& \, - & tmp416/1W, tmp403/1W  \\\hline
# tmp277/1W & \leftarrow \& \, - & tmp276/1W, tmp209/1W  \\\hline
# tmp474/1W & \leftarrow \& \, - & tmp472/1W, tmp473/1W  \\\hline
# tmp187/1W & \leftarrow \& \, - & tmp186/1W, tmp171/1W  \\\hline
# tmp261/1W & \leftarrow \& \, - & tmp260/1W, tmp220/1W  \\\hline
# tmp561/1W & \leftarrow \& \, - & tmp559/1W, tmp560/1W  \\\hline
# tmp579/1W & \leftarrow \& \, - & tmp577/1W, tmp578/1W  \\\hline
# tmp456/1W & \leftarrow \& \, - & tmp455/1W, tmp440/1W  \\\hline
# tmp626/1W & \leftarrow \& \, - & tmp625/1W, tmp584/1W  \\\hline
# tmp524/1W & \leftarrow \& \, - & tmp523/1W, tmp481/1W  \\\hline
# tmp603/1W & \leftarrow \& \, - & tmp601/1W, tmp602/1W  \\\hline
# tmp235/1W & \leftarrow \& \, - & tmp234/1W, tmp223/1W  \\\hline
# tmp387/1W & \leftarrow \& \, - & tmp386/1W, tmp373/1W  \\\hline
# tmp580/1W & \leftarrow \& \, - & tmp579/1W, tmp546/1W  \\\hline
# tmp188/1W & \leftarrow \& \, - & tmp187/1W, tmp174/1W  \\\hline
# tmp657/3W & \leftarrow x \, - & tmp356/1W, tmp656/3W, const\_15\_5/3C  \\\hline
# tmp249/1W & \leftarrow \& \, - & tmp247/1W, tmp248/1W  \\\hline
# tmp299/1W & \leftarrow \& \, - & tmp298/1W, tmp283/1W  \\\hline
# tmp208/1W & \leftarrow \& \, - & tmp207/1W, tmp192/1W  \\\hline
# tmp340/1W & \leftarrow \& \, - & tmp338/1W, tmp339/1W  \\\hline
# tmp418/1W & \leftarrow \& \, - & tmp417/1W, tmp404/1W  \\\hline
# tmp279/1W & \leftarrow \& \, - & tmp277/1W, tmp278/1W  \\\hline
# tmp604/1W & \leftarrow \& \, - & tmp603/1W, tmp584/1W  \\\hline
# tmp475/1W & \leftarrow \& \, - & tmp474/1W, tmp437/1W  \\\hline
# tmp511/1W & \leftarrow \& \, - & tmp510/1W, tmp497/1W  \\\hline
# tmp319/1W & \leftarrow \& \, - & tmp318/1W, tmp303/1W  \\\hline
# tmp562/1W & \leftarrow \& \, - & tmp561/1W, tmp546/1W  \\\hline
# tmp543/1W & \leftarrow \& \, - & tmp541/1W, tmp542/1W  \\\hline
# tmp665/3W & \leftarrow x \, - & tmp127/1W, tmp664/3W, const\_14\_4/3C  \\\hline
# tmp493/1W & \leftarrow \& \, - & tmp492/1W, tmp481/1W  \\\hline
# tmp605/1W & \leftarrow \& \, - & tmp604/1W, tmp587/1W  \\\hline
# tmp582/1W & \leftarrow \& \, - & tmp580/1W, tmp581/1W  \\\hline
# tmp525/1W & \leftarrow \& \, - & tmp524/1W, tmp494/1W  \\\hline
# tmp250/1W & \leftarrow \& \, - & tmp249/1W, tmp236/1W  \\\hline
# tmp583/1W & \leftarrow \& \, - & tmp582/1W, tmp565/1W  \\\hline
# tmp263/1W & \leftarrow \& \, - & tmp261/1W, tmp262/1W  \\\hline
# tmp265/1W & \leftarrow \& \, - & tmp263/1W, tmp264/1W  \\\hline
# tmp628/1W & \leftarrow \& \, - & tmp626/1W, tmp627/1W  \\\hline
# tmp563/1W & \leftarrow \& \, - & tmp562/1W, tmp547/1W  \\\hline
# tmp545/1W & \leftarrow \& \, - & tmp543/1W, tmp544/1W  \\\hline
# tmp477/1W & \leftarrow \& \, - & tmp475/1W, tmp476/1W  \\\hline
# tmp629/1W & \leftarrow \& \, - & tmp628/1W, tmp609/1W  \\\hline
# tmp341/1W & \leftarrow \& \, - & tmp340/1W, tmp323/1W  \\\hline
# tmp658/3W & \leftarrow x \, - & tmp493/1W, tmp657/3W, const\_16\_6/3C  \\\hline
# tmp280/1W & \leftarrow \& \, - & tmp279/1W, tmp266/1W  \\\hline
# tmp527/1W & \leftarrow \& \, - & tmp525/1W, tmp526/1W  \\\hline
# tmp478/1W & \leftarrow \& \, - & tmp477/1W, tmp460/1W  \\\hline
# tmp659/3W & \leftarrow x \, - & tmp639/1W, tmp658/3W, const\_11\_1/3C  \\\hline
# tmp528/1W & \leftarrow \& \, - & tmp527/1W, tmp512/1W  \\\hline
# tmp666/3W & \leftarrow x \, - & tmp140/1W, tmp665/3W, const\_12\_2/3C  \\\hline
# tmp660/3W & \leftarrow x \, - & tmp650/1W, tmp659/3W, const\_10\_0/3C  \\\hline
# tmp667/3W & \leftarrow x \, - & tmp154/1W, tmp666/3W, const\_13\_3/3C  \\\hline
# state\_water/3R & \leftarrow r \, - & tmp660/3W  \\\hline
# tmp668/3W & \leftarrow x \, - & tmp170/1W, tmp667/3W, const\_12\_2/3C  \\\hline
# tmp281/1W & \leftarrow \& \, - & tmp280/1W, tmp267/1W  \\\hline
# tmp669/3W & \leftarrow x \, - & tmp188/1W, tmp668/3W, const\_14\_4/3C  \\\hline
# tmp670/3W & \leftarrow x \, - & tmp208/1W, tmp669/3W, const\_12\_2/3C  \\\hline
# tmp671/3W & \leftarrow x \, - & tmp235/1W, tmp670/3W, const\_13\_3/3C  \\\hline
# tmp672/3W & \leftarrow x \, - & tmp250/1W, tmp671/3W, const\_14\_4/3C  \\\hline
# tmp673/3W & \leftarrow x \, - & tmp265/1W, tmp672/3W, const\_12\_2/3C  \\\hline
# tmp674/3W & \leftarrow x \, - & tmp281/1W, tmp673/3W, const\_13\_3/3C  \\\hline
# tmp675/3W & \leftarrow x \, - & tmp299/1W, tmp674/3W, const\_12\_2/3C  \\\hline
# tmp676/3W & \leftarrow x \, - & tmp319/1W, tmp675/3W, const\_14\_4/3C  \\\hline
# tmp677/3W & \leftarrow x \, - & tmp341/1W, tmp676/3W, const\_12\_2/3C  \\\hline
# tmp678/3W & \leftarrow x \, - & tmp372/1W, tmp677/3W, const\_13\_3/3C  \\\hline
# tmp679/3W & \leftarrow x \, - & tmp387/1W, tmp678/3W, const\_14\_4/3C  \\\hline
# tmp680/3W & \leftarrow x \, - & tmp402/1W, tmp679/3W, const\_12\_2/3C  \\\hline
# tmp681/3W & \leftarrow x \, - & tmp418/1W, tmp680/3W, const\_13\_3/3C  \\\hline
# tmp682/3W & \leftarrow x \, - & tmp436/1W, tmp681/3W, const\_12\_2/3C  \\\hline
# tmp683/3W & \leftarrow x \, - & tmp456/1W, tmp682/3W, const\_14\_4/3C  \\\hline
# tmp684/3W & \leftarrow x \, - & tmp478/1W, tmp683/3W, const\_12\_2/3C  \\\hline
# tmp685/3W & \leftarrow x \, - & tmp511/1W, tmp684/3W, const\_13\_3/3C  \\\hline
# tmp686/3W & \leftarrow x \, - & tmp528/1W, tmp685/3W, const\_14\_4/3C  \\\hline
# tmp687/3W & \leftarrow x \, - & tmp545/1W, tmp686/3W, const\_12\_2/3C  \\\hline
# tmp688/3W & \leftarrow x \, - & tmp563/1W, tmp687/3W, const\_13\_3/3C  \\\hline
# tmp689/3W & \leftarrow x \, - & tmp583/1W, tmp688/3W, const\_12\_2/3C  \\\hline
# tmp690/3W & \leftarrow x \, - & tmp605/1W, tmp689/3W, const\_14\_4/3C  \\\hline
# tmp691/3W & \leftarrow x \, - & tmp629/1W, tmp690/3W, const\_12\_2/3C  \\\hline
# tmp692/3W & \leftarrow x \, - & tmp649/1W, tmp691/3W, const\_11\_1/3C  \\\hline
# tmp693/3W & \leftarrow x \, - & tmp651/1W, tmp692/3W, const\_10\_0/3C  \\\hline
# state\_temperature/3R & \leftarrow r \, - & tmp693/3W  \\\hline
# \end{array}
#
#
# --- Simulation Results ---
# <script type="WaveDrom">
# {
#   signal : [
#     { name: "start",  wave: "1....................0." },
#     { name: "reset",  wave: "010...................." },
#     { name: "water",  wave: "========.==.=.=======..", data: ["0x0", "0x1", "0x2", "0x3", "0x4", "0x5", "0x6", "0x7", "0xd", "0xe", "0xf", "0xe", "0xd", "0x7", "0x6", "0x5", "0x4", "0x3"] },
#     { name: "pump",  wave: "01...........0.....1..0" },
#     { name: "temperature",  wave: "=========..==.=.====...", data: ["0x0", "0x1", "0x2", "0x1", "0x2", "0x3", "0x4", "0x5", "0x6", "0x5", "0x4", "0x3", "0x4", "0x5", "0x6", "0x1"] },
#     { name: "ac",  wave: "=...=..=.=.....=...====", data: ["0x0", "0x3", "0x0", "0x1", "0x0", "0x1", "0x0", "0x3", "0x0"] },
#     { name: "state_water",  wave: "==.=.........=.....=..=", data: ["0x0", "0x1", "0x5", "0x6", "0x5", "0x0"] },
#     { name: "state_temperature",  wave: "==.==..=.=.....=...====", data: ["0x0", "0x1", "0x2", "0x3", "0x2", "0x4", "0x2", "0x4", "0x2", "0x3", "0x0"] },
#   ],
#   config: { hscale: 1 }
# }
# </script>
# --- Verilog for the TestBench ---
# module tb();
#     reg clk;
#     reg rst;
#     reg reset;
#     reg start;
#     reg[2:0] temperature;
#     reg[3:0] water;
#     wire[1:0] ac;
#     wire pump;
#
#     integer tb_iter;
#     toplevel block(.clk(clk), .rst(rst), .reset(reset), .start(start), .temperature(temperature), .water(water), .ac(ac), .pump(pump));
#
#     always
#         #5 clk = ~clk;
#
#     initial begin
#         $dumpfile ("waveform.vcd");
#         $dumpvars;
#
#         clk = 0;
#         rst = 0;
#         block.state_temperature = 0;
#         block.state_water = 0;
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd0;
#         water = 4'd0;
#
#         #10
#         reset = 1'd1;
#         start = 1'd1;
#         temperature = 3'd1;
#         water = 4'd1;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd2;
#         water = 4'd2;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd1;
#         water = 4'd3;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd2;
#         water = 4'd4;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd3;
#         water = 4'd5;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd4;
#         water = 4'd6;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd5;
#         water = 4'd7;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd6;
#         water = 4'd7;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd6;
#         water = 4'd13;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd6;
#         water = 4'd14;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd5;
#         water = 4'd14;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd4;
#         water = 4'd15;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd4;
#         water = 4'd15;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd3;
#         water = 4'd14;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd3;
#         water = 4'd13;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd4;
#         water = 4'd7;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd5;
#         water = 4'd6;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd6;
#         water = 4'd5;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd1;
#         water = 4'd4;
#
#         #10
#         reset = 1'd0;
#         start = 1'd1;
#         temperature = 3'd1;
#         water = 4'd3;
#
#         #10
#         reset = 1'd0;
#         start = 1'd0;
#         temperature = 3'd1;
#         water = 4'd3;
#
#         #10
#         reset = 1'd0;
#         start = 1'd0;
#         temperature = 3'd1;
#         water = 4'd3;
#
#         #10
#         $finish;
#     end
# endmodule
#
# // Generated automatically via PyRTL
# // As one initial test of synthesis, map to FPGA with:
# //   yosys -p "synth_xilinx -top toplevel" thisfile.v
#
# module toplevel(clk, rst, reset, start, temperature, water, ac, pump);
#     input clk;
#     input rst;
#     input reset;
#     input start;
#     input[2:0] temperature;
#     input[3:0] water;
#     output[1:0] ac;
#     output pump;
#
#     reg state_temperature_synth_0;
#     reg state_temperature_synth_1;
#     reg state_temperature_synth_2;
#     reg state_water_synth_0;
#     reg state_water_synth_1;
#     reg state_water_synth_2;
#
#     wire tmp2014;
#     wire tmp2015;
#     wire tmp2016;
#     wire tmp2017;
#     wire tmp2020;
#     wire tmp2021;
#     wire[1:0] tmp2023;
#     wire tmp2026;
#     wire tmp2027;
#     wire tmp2028;
#     wire tmp2029;
#     wire tmp2031;
#     wire tmp2032;
#     wire tmp2034;
#     wire tmp2036;
#     wire tmp2037;
#     wire tmp2038;
#     wire tmp2040;
#     wire tmp2041;
#     wire tmp2047;
#     wire tmp2051;
#     wire tmp2053;
#     wire tmp2060;
#     wire tmp2061;
#     wire tmp2062;
#     wire tmp2066;
#     wire tmp2070;
#     wire tmp2072;
#     wire tmp2074;
#     wire tmp2084;
#     wire tmp2085;
#     wire tmp2086;
#     wire tmp2099;
#     wire tmp2100;
#     wire tmp2102;
#     wire tmp2103;
#     wire tmp2105;
#     wire tmp2106;
#     wire tmp2107;
#     wire tmp2115;
#     wire tmp2120;
#     wire tmp2137;
#     wire tmp2140;
#     wire tmp2141;
#     wire tmp2148;
#     wire tmp2157;
#     wire tmp2158;
#     wire tmp2159;
#     wire tmp2164;
#     wire tmp2166;
#     wire tmp2172;
#     wire tmp2175;
#     wire tmp2176;
#     wire tmp2177;
#     wire tmp2200;
#     wire tmp2201;
#     wire tmp2204;
#     wire tmp2214;
#     wire tmp2225;
#     wire tmp2226;
#     wire tmp2228;
#     wire tmp2229;
#     wire tmp2230;
#     wire tmp2237;
#     wire tmp2240;
#     wire tmp2248;
#     wire tmp2250;
#     wire tmp2251;
#     wire tmp2254;
#     wire tmp2262;
#     wire tmp2286;
#     wire tmp2287;
#     wire tmp2288;
#     wire tmp2298;
#     wire tmp2300;
#     wire tmp2301;
#     wire tmp2304;
#     wire tmp2310;
#     wire tmp2311;
#     wire tmp2312;
#     wire tmp2313;
#     wire tmp2314;
#     wire tmp2315;
#     wire tmp2317;
#     wire tmp2319;
#     wire tmp2320;
#     wire tmp2321;
#     wire tmp2329;
#     wire tmp2330;
#     wire tmp2331;
#     wire tmp2332;
#     wire tmp2333;
#     wire tmp2334;
#     wire tmp2336;
#     wire tmp2337;
#     wire tmp2338;
#     wire tmp2352;
#     wire tmp2354;
#     wire tmp2356;
#     wire tmp2357;
#     wire tmp2360;
#     wire tmp2362;
#     wire tmp2363;
#     wire tmp2370;
#     wire tmp2371;
#     wire tmp2372;
#     wire tmp2373;
#     wire tmp2374;
#     wire tmp2375;
#     wire tmp2377;
#     wire tmp2390;
#     wire tmp2393;
#     wire tmp2405;
#     wire tmp2407;
#     wire tmp2411;
#     wire tmp2412;
#     wire tmp2413;
#     wire tmp2424;
#     wire tmp2431;
#     wire tmp2448;
#     wire tmp2449;
#     wire tmp2450;
#     wire tmp2452;
#     wire tmp2457;
#     wire tmp2459;
#     wire tmp2460;
#     wire tmp2461;
#     wire tmp2463;
#     wire tmp2465;
#     wire tmp2473;
#     wire tmp2476;
#     wire tmp2482;
#     wire tmp2483;
#     wire tmp2484;
#     wire tmp2489;
#     wire tmp2492;
#     wire tmp2493;
#     wire tmp2498;
#     wire tmp2499;
#     wire tmp2500;
#     wire tmp2509;
#     wire tmp2522;
#     wire tmp2525;
#     wire tmp2527;
#     wire tmp2531;
#     wire tmp2532;
#     wire tmp2533;
#     wire tmp2534;
#     wire tmp2535;
#     wire tmp2539;
#     wire tmp2548;
#     wire tmp2556;
#     wire tmp2570;
#     wire tmp2571;
#     wire tmp2572;
# ...
#     wire tmp3333;
#     wire tmp3335;
#     wire tmp3349;
#     wire tmp3362;
#     wire tmp3363;
#     wire tmp3372;
#     wire tmp3375;
#     wire tmp3380;
#     wire tmp3399;
#     wire tmp3403;
#     wire tmp3412;
#     wire tmp3414;
#     wire tmp3416;
#     wire tmp3419;
#     wire tmp3426;
#     wire tmp3427;
#     wire tmp3428;
#     wire tmp3430;
#     wire tmp3431;
#     wire tmp3432;
#     wire tmp3436;
#     wire tmp3440;
#     wire tmp3445;
#     wire tmp3446;
#     wire tmp3449;
#     wire tmp3450;
#     wire tmp3451;
#     wire tmp3456;
#     wire tmp3467;
#     wire tmp3468;
#     wire tmp3469;
#     wire tmp3473;
#     wire tmp3475;
#     wire tmp3482;
#     wire tmp3486;
#     wire tmp3487;
#     wire tmp3488;
#     wire tmp3489;
#     wire tmp3493;
#     wire tmp3495;
#     wire tmp3502;
#     wire tmp3506;
#     wire tmp3516;
#     wire tmp3529;
#     wire tmp3536;
#     wire tmp3538;
#     wire tmp3539;
#     wire tmp3541;
#     wire tmp3550;
#     wire tmp3559;
#
#     // Combinational
#     assign ac = tmp2023;
#     assign pump = tmp3308;
#     assign tmp2014 = {water[0]};
#     assign tmp2015 = {water[1]};
#     assign tmp2016 = {water[2]};
#     assign tmp2017 = {water[3]};
#     assign tmp2020 = {temperature[1]};
#     assign tmp2021 = {temperature[2]};
#     assign tmp2023 = {tmp2811, tmp3091};
#     assign tmp2026 = tmp2500 | tmp2072;
#     assign tmp2027 = tmp3048 & tmp3493;
#     assign tmp2028 = tmp3088 & tmp3493;
#     assign tmp2029 = tmp3089 & tmp3493;
#     assign tmp2031 = tmp2660 & tmp3278;
#     assign tmp2032 = ~tmp3298;
#     assign tmp2034 = start & tmp2304;
#     assign tmp2036 = tmp3062 & tmp2074;
#     assign tmp2037 = tmp2352 & tmp2074;
#     assign tmp2038 = tmp3064 & tmp2074;
#     assign tmp2040 = tmp2691 | tmp2248;
#     assign tmp2041 = tmp2692 | tmp2248;
#     assign tmp2047 = ~tmp2878;
#     assign tmp2051 = tmp2237 & tmp3302;
#     assign tmp2053 = tmp2962 | tmp2621;
#     assign tmp2060 = tmp2336 & tmp3181;
#     assign tmp2061 = tmp2405 & tmp3181;
#     assign tmp2062 = tmp2338 & tmp3181;
#     assign tmp2066 = tmp3416 & tmp2623;
#     assign tmp2070 = ~tmp2047;
#     assign tmp2072 = tmp3108 & tmp2021;
#     assign tmp2074 = ~tmp2115;
#     assign tmp2084 = tmp2356 & tmp2835;
#     assign tmp2085 = tmp2357 & tmp2835;
#     assign tmp2086 = tmp2315 & tmp2835;
#     assign tmp2099 = state_temperature_synth_1 | tmp3436;
#     assign tmp2100 = tmp2390 & tmp3278;
#     assign tmp2102 = tmp2531 | tmp3183;
#     assign tmp2103 = tmp2532 | tmp3183;
#     assign tmp2105 = tmp2589 & tmp2465;
#     assign tmp2106 = tmp2974 & tmp2465;
#     assign tmp2107 = tmp2975 & tmp2465;
#     assign tmp2115 = tmp3307 & tmp3536;
#     assign tmp2120 = ~tmp3127;
#     assign tmp2137 = ~tmp2606;
#     assign tmp2140 = ~tmp2072;
#     assign tmp2141 = tmp2105 | tmp2879;
#     assign tmp2148 = ~tmp2254;
#     assign tmp2157 = tmp2457 & tmp2961;
#     assign tmp2158 = tmp2175 | tmp2696;
#     assign tmp2159 = tmp2176 | tmp2696;
#     assign tmp2164 = tmp2204 & tmp3302;
#     assign tmp2166 = tmp2230 & tmp3194;
#     assign tmp2172 = tmp2062 | tmp3238;
#     assign tmp2175 = tmp2411 & tmp2638;
#     assign tmp2176 = tmp2775 & tmp2638;
#     assign tmp2177 = tmp2413 & tmp2638;
#     assign tmp2200 = ~tmp2100;
#     assign tmp2201 = tmp3380 & tmp3274;
#     assign tmp2204 = tmp3012 & tmp3306;
#     assign tmp2214 = tmp2849 & tmp2021;
#     assign tmp2225 = tmp3074 | tmp2031;
#     assign tmp2226 = tmp3075 | tmp2031;
#     assign tmp2228 = state_temperature_synth_0 | tmp2099;
#     assign tmp2229 = tmp2966 & tmp3065;
#     assign tmp2230 = tmp3145 & tmp2377;
#     assign tmp2237 = tmp3056 & tmp3306;
#     assign tmp2240 = tmp2635 | tmp2201;
#     assign tmp2248 = tmp3191 & tmp3278;
#     assign tmp2250 = state_temperature_synth_0 | tmp2452;
#     assign tmp2251 = ~tmp2473;
#     assign tmp2254 = tmp3041 & tmp3536;
#     assign tmp2262 = tmp2660 & tmp2623;
#     assign tmp2286 = state_water_synth_0 & tmp2354;
#     assign tmp2287 = state_water_synth_1 & tmp2354;
#     assign tmp2288 = state_water_synth_2 & tmp2354;
#     assign tmp2298 = ~tmp2682;
#     assign tmp2300 = tmp2808 & tmp3306;
#     assign tmp2301 = tmp3191 & tmp2623;
#     assign tmp2304 = ~reset;
#     assign tmp2310 = tmp2333 & tmp2393;
#     assign tmp2311 = tmp2334 & tmp2393;
#     assign tmp2312 = tmp2461 & tmp2393;
#     assign tmp2313 = tmp3080 & tmp2137;
#     assign tmp2314 = tmp2931 & tmp2137;
#     assign tmp2315 = tmp3082 & tmp2137;
#     assign tmp2317 = tmp3041 & tmp3482;
#     assign tmp2319 = tmp2084 & tmp2032;
#     assign tmp2320 = tmp2085 & tmp2032;
#     assign tmp2321 = tmp3282 & tmp2032;
#     assign tmp2329 = ~tmp3349;
#     assign tmp2330 = tmp2310 & tmp3335;
#     assign tmp2331 = tmp2360 & tmp3335;
#     assign tmp2332 = tmp2312 & tmp3335;
#     assign tmp2333 = tmp2459 | tmp2473;
#     assign tmp2334 = tmp2460 | tmp2473;
#     assign tmp2336 = tmp2102 & tmp2719;
#     assign tmp2337 = tmp2103 & tmp2719;
#     assign tmp2338 = tmp2533 & tmp2719;
#     assign tmp2352 = tmp3063 | tmp3529;
#     assign tmp2354 = ~tmp2632;
#     assign tmp2356 = tmp2313 | tmp2606;
#     assign tmp2357 = tmp2314 | tmp2606;
#     assign tmp2360 = tmp2311 | tmp2509;
#     assign tmp2362 = state_temperature_synth_0 | tmp2621;
#     assign tmp2363 = ~tmp2808;
#     assign tmp2370 = tmp3538 & tmp2493;
#     assign tmp2371 = tmp3539 & tmp2493;
#     assign tmp2372 = tmp3428 & tmp2493;
#     assign tmp2373 = tmp3487 & tmp3246;
#     assign tmp2374 = tmp3155 & tmp3246;
#     assign tmp2375 = tmp3156 & tmp3246;
#     assign tmp2377 = ~tmp3440;
#     assign tmp2390 = tmp2998 & tmp3278;
#     assign tmp2393 = ~tmp2509;
#     assign tmp2405 = tmp2337 | tmp2066;
#     assign tmp2407 = state_water_synth_0 | tmp3214;
#     assign tmp2411 = tmp2060 & tmp2200;
#     assign tmp2412 = tmp2061 & tmp2200;
#     assign tmp2413 = tmp2172 & tmp2200;
#     assign tmp2424 = tmp3012 & tmp3456;
#     assign tmp2431 = tmp2237 & tmp3070;
#     assign tmp2448 = tmp3330 & tmp2810;
#     assign tmp2449 = tmp2726 & tmp2810;
#     assign tmp2450 = tmp3332 & tmp2810;
#     assign tmp2452 = tmp2963 | state_temperature_synth_2;
#     assign tmp2457 = tmp2424 & tmp3482;
#     assign tmp2459 = tmp3467 & tmp2251;
#     assign tmp2460 = tmp2958 & tmp2251;
#     assign tmp2461 = tmp3469 & tmp2251;
#     assign tmp2463 = ~state_water_synth_1;
#     assign tmp2465 = ~tmp2879;
#     assign tmp2473 = tmp2051 & tmp3278;
#     assign tmp2476 = tmp2651 | tmp3094;
#     assign tmp2482 = tmp2141 & tmp3375;
#     assign tmp2483 = tmp2106 & tmp3375;
#     assign tmp2484 = tmp2107 & tmp3375;
#     assign tmp2489 = ~tmp2675;
#     assign tmp2492 = ~tmp3323;
#     assign tmp2493 = ~tmp3372;
#     assign tmp2498 = tmp3157 & tmp2140;
#     assign tmp2499 = tmp2668 & tmp2140;
#     assign tmp2500 = tmp3159 & tmp2140;
#     assign tmp2509 = tmp3032 & tmp2623;
#     assign tmp2522 = tmp2527 & tmp3278;
#     assign tmp2525 = ~tmp3012;
#     assign tmp2527 = tmp2849 & tmp3278;
#     assign tmp2531 = tmp2319 & tmp2698;
#     assign tmp2532 = tmp2995 & tmp2698;
#     assign tmp2533 = tmp2321 & tmp2698;
#     assign tmp2534 = ~tmp3072;
#     assign tmp2535 = ~tmp3309;
#     assign tmp2539 = ~tmp3204;
#     assign tmp2548 = tmp2014 & tmp3287;
#     assign tmp2556 = ~state_water_synth_0;
#     assign tmp2570 = tmp2370 & tmp2329;
#     assign tmp2571 = tmp2371 & tmp2329;
#     assign tmp2572 = tmp2751 & tmp2329;
#     assign tmp2585 = tmp2924 & tmp3375;
#     assign tmp2586 = tmp3450 & tmp3375;
#     assign tmp2587 = tmp3451 & tmp3375;
#     assign tmp2589 = tmp2720 & tmp2535;
#     assign tmp2590 = tmp2374 & tmp2535;
#     assign tmp2591 = tmp2722 & tmp2535;
#     assign tmp2606 = tmp2424 & tmp3536;
#     assign tmp2610 = tmp2027 | tmp3275;
#     assign tmp2612 = tmp2029 | tmp3275;
#     assign tmp2621 = state_temperature_synth_1 | state_temperature_synth_2;
#     assign tmp2623 = ~tmp3278;
#     assign tmp2632 = start & reset;
#     assign tmp2634 = tmp3430 & tmp2703;
#     assign tmp2635 = tmp3431 & tmp2703;
#     assign tmp2636 = tmp2982 & tmp2703;
#     assign tmp2638 = ~tmp2696;
#     assign tmp2650 = tmp3403 & tmp2895;
#     assign tmp2651 = tmp2658 & tmp2895;
#     assign tmp2652 = tmp2659 & tmp2895;
#     assign tmp2657 = tmp2770 & tmp2539;
#     assign tmp2658 = tmp3253 & tmp2539;
#     assign tmp2659 = tmp3254 & tmp2539;
#     assign tmp2660 = tmp3559 & tmp3302;
#     assign tmp2663 = ~tmp2522;
#     assign tmp2668 = tmp3158 | tmp3245;
#     assign tmp2675 = ~tmp3110;
#     assign tmp2682 = tmp2034 & tmp3127;
#     assign tmp2691 = tmp2570 & tmp3077;
#     assign tmp2692 = tmp2841 & tmp3077;
#     assign tmp2693 = tmp2572 & tmp3077;
#     assign tmp2696 = tmp3068 & tmp3536;
#     assign tmp2698 = ~tmp3183;
#     assign tmp2703 = ~tmp2201;
#     assign tmp2719 = ~tmp2066;
#     assign tmp2720 = tmp2373 | tmp3056;
#     assign tmp2722 = tmp2375 | tmp3056;
#     assign tmp2726 = tmp3331 | tmp3333;
#     assign tmp2730 = ~tmp2016;
#     assign tmp2751 = tmp2372 | tmp3372;
#     assign tmp2760 = ~tmp2053;
#     assign tmp2770 = tmp3252 | tmp2632;
#     assign tmp2775 = tmp2412 | tmp2100;
#     assign tmp2781 = ~tmp3529;
#     assign tmp2796 = ~tmp2362;
#     assign tmp2808 = tmp2230 & tmp2492;
#     assign tmp2810 = ~tmp2214;
#     assign tmp2811 = tmp3302 ^ tmp2923;
#     assign tmp2813 = ~tmp3301;
#     assign tmp2816 = tmp3506 & tmp3278;
#     assign tmp2823 = tmp2914 & tmp3278;
#     assign tmp2830 = ~tmp3263;
#     assign tmp2835 = ~tmp2157;
#     assign tmp2841 = tmp2571 | tmp3349;
#     assign tmp2846 = ~tmp2020;
#     assign tmp2849 = tmp3066 & tmp3019;
#     assign tmp2852 = tmp2548 & tmp3495;
#     assign tmp2860 = tmp2158 & tmp2830;
#     assign tmp2861 = tmp2159 & tmp2830;
#     assign tmp2862 = tmp2177 & tmp2830;
#     assign tmp2875 = tmp2962 | tmp2452;
#     assign tmp2878 = tmp2556 | tmp2965;
#     assign tmp2879 = tmp3293 & tmp2534;
#     assign tmp2888 = ~tmp3067;
#     assign tmp2895 = ~tmp3094;
#     assign tmp2904 = ~tmp2015;
#     assign tmp2914 = tmp2431 & tmp3019;
#     assign tmp2923 = tmp3302 & tmp3019;
#     assign tmp2924 = tmp3449 | tmp2879;
#     assign tmp2931 = tmp3081 | tmp2816;
#     assign tmp2951 = tmp3103 & tmp2489;
#     assign tmp2953 = ~tmp3245;
#     assign tmp2958 = tmp3468 | tmp3067;
#     assign tmp2961 = tmp2020 & tmp2623;
#     assign tmp2962 = ~state_temperature_synth_0;
#     assign tmp2963 = ~state_temperature_synth_1;
#     assign tmp2965 = state_water_synth_1 | state_water_synth_2;
#     assign tmp2966 = tmp2015 & tmp3495;
#     assign tmp2974 = tmp2590 | tmp3309;
#     assign tmp2975 = tmp2591 | tmp3309;
#     assign tmp2982 = tmp3432 | tmp3301;
#     assign tmp2983 = ~tmp3065;
#     assign tmp2987 = ~state_water_synth_2;
#     assign tmp2989 = tmp2300 & tmp3070;
#     assign tmp2995 = tmp2320 | tmp3298;
#     assign tmp2998 = tmp3414 & tmp3019;
#     assign tmp3012 = tmp2166 & tmp3323;
#     assign tmp3019 = ~tmp2228;
#     assign tmp3026 = tmp2610 & tmp2363;
#     assign tmp3027 = tmp2028 & tmp2363;
#     assign tmp3028 = tmp2612 & tmp2363;
#     assign tmp3032 = tmp2051 & tmp2623;
#     assign tmp3041 = tmp2808 & tmp3456;
#     assign tmp3048 = tmp3087 | tmp2682;
#     assign tmp3051 = ~tmp2816;
#     assign tmp3056 = tmp3103 & tmp2675;
#     assign tmp3062 = tmp2330 & tmp2781;
#     assign tmp3063 = tmp2331 & tmp2781;
#     assign tmp3064 = tmp3207 & tmp2781;
#     assign tmp3065 = ~tmp2017;
#     assign tmp3066 = tmp3559 & tmp3070;
#     assign tmp3067 = tmp3412 & tmp3274;
#     assign tmp3068 = tmp3056 & tmp3456;
#     assign tmp3070 = ~tmp3302;
#     assign tmp3072 = ~tmp2407;
#     assign tmp3074 = tmp2634 & tmp3083;
#     assign tmp3075 = tmp2240 & tmp3083;
#     assign tmp3076 = tmp2636 & tmp3083;
#     assign tmp3077 = ~tmp2248;
#     assign tmp3080 = tmp2498 & tmp3051;
#     assign tmp3081 = tmp2499 & tmp3051;
#     assign tmp3082 = tmp2026 & tmp3051;
#     assign tmp3083 = ~tmp2031;
#     assign tmp3087 = tmp3168 & tmp2298;
#     assign tmp3088 = tmp2287 & tmp2298;
#     assign tmp3089 = tmp2288 & tmp2298;
#     assign tmp3091 = tmp3302 ^ tmp3019;
#     assign tmp3094 = tmp3275 & tmp2760;
#     assign tmp3103 = tmp3293 & tmp3072;
#     assign tmp3108 = tmp2989 & tmp3019;
#     assign tmp3110 = tmp2017 | tmp2229;
#     assign tmp3127 = ~tmp3541;
#     assign tmp3145 = tmp3363 & tmp2070;
#     assign tmp3155 = tmp3488 | tmp3012;
#     assign tmp3156 = tmp3489 | tmp3012;
#     assign tmp3157 = tmp2040 & tmp2953;
#     assign tmp3158 = tmp2041 & tmp2953;
#     assign tmp3159 = tmp2693 & tmp2953;
#     assign tmp3168 = tmp2286 | tmp2632;
#     assign tmp3181 = ~tmp3238;
#     assign tmp3183 = tmp2164 & tmp3278;
#     assign tmp3191 = tmp2300 & tmp3302;
#     assign tmp3194 = ~tmp2492;
#     assign tmp3204 = tmp2682 & tmp2796;
#     assign tmp3207 = tmp2332 | tmp3502;
#     assign tmp3214 = tmp2463 | tmp2987;
#     assign tmp3224 = tmp3318 | tmp2522;
#     assign tmp3238 = tmp2998 & tmp2021;
#     assign tmp3245 = tmp2301 & tmp2623;
#     assign tmp3246 = ~tmp3056;
#     assign tmp3252 = state_temperature_synth_0 & tmp2354;
#     assign tmp3253 = state_temperature_synth_1 & tmp2354;
#     assign tmp3254 = state_temperature_synth_2 & tmp2354;
#     assign tmp3263 = tmp3412 & tmp2961;
#     assign tmp3274 = ~tmp2961;
#     assign tmp3275 = tmp3363 & tmp2047;
#     assign tmp3278 = ~tmp2021;
#     assign tmp3282 = tmp2086 | tmp2157;
#     assign tmp3287 = ~tmp2904;
#     assign tmp3293 = tmp3145 & tmp3550;
#     assign tmp3298 = tmp2457 & tmp3274;
#     assign tmp3301 = tmp3380 & tmp2961;
#     assign tmp3302 = ~tmp2875;
#     assign tmp3306 = ~tmp3456;
#     assign tmp3307 = tmp3309 & tmp3456;
#     assign tmp3308 = tmp2047 | tmp2377;
#     assign tmp3309 = tmp2951 & tmp3110;
#     assign tmp3317 = tmp2448 & tmp2663;
#     assign tmp3318 = tmp2449 & tmp2663;
#     assign tmp3319 = tmp3362 & tmp2663;
#     assign tmp3323 = tmp2852 & tmp2983;
#     assign tmp3330 = tmp2225 & tmp3419;
#     assign tmp3331 = tmp2226 & tmp3419;
#     assign tmp3332 = tmp3076 & tmp3419;
#     assign tmp3333 = tmp2262 & tmp2623;
#     assign tmp3335 = ~tmp3502;
#     assign tmp3349 = tmp2317 & tmp3274;
#     assign tmp3362 = tmp2450 | tmp2214;
#     assign tmp3363 = tmp2034 & tmp2120;
#     assign tmp3372 = tmp2317 & tmp2961;
#     assign tmp3375 = ~tmp3399;
#     assign tmp3380 = tmp3307 & tmp3482;
#     assign tmp3399 = ~start;
#     assign tmp3403 = tmp2657 | tmp3204;
#     assign tmp3412 = tmp3068 & tmp3482;
#     assign tmp3414 = tmp2204 & tmp3070;
#     assign tmp3416 = tmp2164 & tmp2623;
#     assign tmp3419 = ~tmp3333;
#     assign tmp3426 = tmp2650 & tmp2148;
#     assign tmp3427 = tmp2476 & tmp2148;
#     assign tmp3428 = tmp2652 & tmp2148;
#     assign tmp3430 = tmp3445 & tmp2813;
#     assign tmp3431 = tmp3446 & tmp2813;
#     assign tmp3432 = tmp2038 & tmp2813;
#     assign tmp3436 = ~state_temperature_synth_2;
#     assign tmp3440 = tmp2556 | tmp3516;
#     assign tmp3445 = tmp2036 | tmp2115;
#     assign tmp3446 = tmp2037 | tmp2115;
#     assign tmp3449 = tmp3317 & tmp2465;
#     assign tmp3450 = tmp3224 & tmp2465;
#     assign tmp3451 = tmp3319 & tmp2465;
#     assign tmp3456 = ~tmp2250;
#     assign tmp3467 = tmp2860 & tmp2888;
#     assign tmp3468 = tmp2861 & tmp2888;
#     assign tmp3469 = tmp3486 & tmp2888;
#     assign tmp3473 = tmp3026 | tmp2808;
#     assign tmp3475 = tmp3028 | tmp2808;
#     assign tmp3482 = ~tmp3536;
#     assign tmp3486 = tmp2862 | tmp3263;
#     assign tmp3487 = tmp3473 & tmp2525;
#     assign tmp3488 = tmp3027 & tmp2525;
#     assign tmp3489 = tmp3475 & tmp2525;
#     assign tmp3493 = ~tmp3275;
#     assign tmp3495 = ~tmp2730;
#     assign tmp3502 = tmp2914 & tmp2021;
#     assign tmp3506 = tmp3108 & tmp3278;
#     assign tmp3516 = state_water_synth_1 | tmp2987;
#     assign tmp3529 = tmp2823 & tmp3278;
#     assign tmp3536 = tmp2846 & tmp3278;
#     assign tmp3538 = tmp3426 | tmp2254;
#     assign tmp3539 = tmp3427 | tmp2254;
#     assign tmp3541 = state_water_synth_0 | tmp2965;
#     assign tmp3550 = ~tmp2377;
#     assign tmp3559 = tmp3309 & tmp3306;
#
#     // Registers
#     always @(posedge clk)
#     begin
#         if (rst) begin
#             state_temperature_synth_0 <= 0;
#             state_temperature_synth_1 <= 0;
#             state_temperature_synth_2 <= 0;
#             state_water_synth_0 <= 0;
#             state_water_synth_1 <= 0;
#             state_water_synth_2 <= 0;
#         end
#         else begin
#             state_temperature_synth_0 <= tmp2585;
#             state_temperature_synth_1 <= tmp2586;
#             state_temperature_synth_2 <= tmp2587;
#             state_water_synth_0 <= tmp2482;
#             state_water_synth_1 <= tmp2483;
#             state_water_synth_2 <= tmp2484;
#         end
#     end
#
# endmodule
